# %%
# Importing libraries
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# Assigning DataFrame objects
nbh = pd.read_csv('~/Documents/JONATHANAYALA-CAPSTONE2/DATA/neighbourhoods.csv')
revs = pd.read_csv('~/Documents/JONATHANAYALA-CAPSTONE2/DATA/reviews.csv')
lsts = pd.read_csv('~/Documents/JONATHANAYALA-CAPSTONE2/DATA/listings.csv')

# %%
# Inspecting DataFrames
nbh.head()
# Out:
#   neighbourhood_group neighbourhood
# 0               Bronx      Allerton
# 1               Bronx    Baychester
# 2               Bronx       Belmont
# 3               Bronx     Bronxdale
# 4               Bronx   Castle Hill

# %%
nbh.shape
# Out:
# (230, 2)

# %%
nbh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230 entries, 0 to 229
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   neighbourhood_group  230 non-null    object
#  1   neighbourhood        230 non-null    object
# dtypes: object(2)
# memory usage: 3.7+ KB

# %%
nbh.describe()
# Out:
#        neighbourhood_group neighbourhood
# count                  230           230
# unique                   5           230
# top                 Queens  Coney Island
# freq                    53             1

# %%
len(nbh)
# Out:
# 230

# %%
revs.head()
# Out:
#    listing_id        date
# 0        2060  2008-09-22
# 1        2595  2009-11-21
# 2        2595  2009-12-05
# 3        2595  2009-12-10
# 4        2595  2010-04-09

# %%
revs.tail()
# Out:
#          listing_id        date
# 1130063    44020492  2020-07-05
# 1130064    44054321  2020-07-06
# 1130065    44083993  2020-07-06
# 1130066    44083993  2020-07-07
# 1130067    44086561  2020-07-07

# %%
revs.shape
# Out:
# (1130068, 2)

# %%
revs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1130068 entries, 0 to 1130067
# Data columns (total 2 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   listing_id  1130068 non-null  int64
#  1   date        1130068 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 17.2+ MB

# %%
revs.describe()
# Out:
#          listing_id
# count  1.130068e+06
# mean   1.463910e+07
# std    1.144450e+07
# min    2.060000e+03
# 25%    4.168812e+06
# 50%    1.353337e+07
# 75%    2.238930e+07
# max    4.408656e+07

# %%
len(revs)
# Out:
# 1130068

# %%
lsts.head()
# Out:
#      id                                               name  host_id  \
# 0  2060                                         Modern NYC     2259
# 1  2595                              Skylit Midtown Castle     2845
# 2  3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
# 3  5054                                       Midtown West     7231
# 4  5099          Large Cozy 1 BR Apartment In Midtown East     7322
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0        Jenny           Manhattan  Washington Heights  40.85722  -73.93790
# 1     Jennifer           Manhattan             Midtown  40.75362  -73.98377
# 2  LisaRoxanne            Brooklyn        Clinton Hill  40.68514  -73.95976
# 3          Tom           Manhattan      Hell's Kitchen  40.76551  -73.98631
# 4        Chris           Manhattan         Murray Hill  40.74767  -73.97500
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
lsts.tail()
# Out:
#              id                                           name    host_id  \
# 48583  44103357      Huge private room in Upper East Manhattan  247439246
# 48584  44103415          Dumbo | Spacious Private Room in LOFT    2420592
# 48585  44103612              Huge private room in Williamsburg  247439246
# 48586  44103854                         Cozy house in Brooklyn  247439246
# 48587  44104534  Stunning, spacious Upper West Side apartment!   74410137
#
#       host_name neighbourhood_group    neighbourhood  latitude  longitude  \
# 48583      Alex           Manhattan      East Harlem  40.79319  -73.94360
# 48584     Lucas            Brooklyn        Navy Yard  40.70231  -73.98032
# 48585      Alex            Brooklyn     Williamsburg  40.71414  -73.96376
# 48586      Alex            Brooklyn         Bushwick  40.69850  -73.93186
# 48587    Jordan           Manhattan  Upper West Side  40.79075  -73.97373
#
# ...

# %%
lsts.shape
# Out:
# (48588, 16)

# %%
lsts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48588 entries, 0 to 48587
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48588 non-null  int64
#  1   name                            48570 non-null  object
#  2   host_id                         48588 non-null  int64
#  3   host_name                       48576 non-null  object
#  4   neighbourhood_group             48588 non-null  object
#  5   neighbourhood                   48588 non-null  object
#  6   latitude                        48588 non-null  float64
#  7   longitude                       48588 non-null  float64
#  8   room_type                       48588 non-null  object
#  9   price                           48588 non-null  int64
#  10  minimum_nights                  48588 non-null  int64
#  11  number_of_reviews               48588 non-null  int64
# ...

# %%
lsts.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.858800e+04  4.858800e+04  48588.000000  48588.000000  48588.000000
# mean   2.306509e+07  8.548647e+07     40.729365    -73.951143    165.583025
# std    1.362972e+07  9.959082e+07      0.054881      0.047500    454.040569
# min    2.060000e+03  2.259000e+03     40.499790    -74.240840      0.000000
# 25%    1.085637e+07  9.232804e+06     40.689920    -73.983380     67.000000
# 50%    2.236088e+07  3.784629e+07     40.724060    -73.955425    100.000000
# 75%    3.577099e+07  1.377744e+08     40.763023    -73.934430    175.000000
# max    4.410453e+07  3.539906e+08     40.911690    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48588.000000       48588.000000       37230.000000
# mean         8.359986          23.258171           0.959229
# std         22.420904          47.616398           1.304544
# ...

# %%
len(lsts)
# Out:
# 48588

# %%
# Assigning DataFrame objects (.gz files)

revs_gz = pd.read_csv('~/Documents/CAPSTONE2-LARGEFILES/reviews.csv.gz', compression='gzip')

# %%
cal_gz = pd.read_csv('~/Documents/JONATHANAYALA-CAPSTONE2/DATA/calendar.csv.gz', compression='gzip')

# %%
lsts_gz = pd.read_csv('~/Documents/JONATHANAYALA-CAPSTONE2/DATA/listings.csv.gz', compression='gzip', low_memory=False)

# %%
# Inspecting .gz file DataFrames (Are they more descriptive?)
revs_gz.head()
# Out:
#    listing_id     id        date  reviewer_id reviewer_name  \
# 0        2060    158  2008-09-22         2865          Thom
# 1        2595  17857  2009-11-21        50679          Jean
# 2        2595  19176  2009-12-05        53267          Cate
# 3        2595  19760  2009-12-10        38960         Anita
# 4        2595  34320  2010-04-09        71130       Kai-Uwe
#
#                                             comments
# 0  very nice neighborhood,close enough to "A" tra...
# 1  Notre séjour de trois nuits.\r\nNous avons app...
# 2                                  Great experience.
# 3  I've stayed with my friend at the Midtown Cast...
# 4  We've been staying here for about 9 nights, en...

# %%
revs_gz.tail()
# Out:
#          listing_id         id        date  reviewer_id     reviewer_name  \
# 1130063    44020492  635042843  2020-07-05     50049551           Jessica
# 1130064    44054321  635457227  2020-07-06    353632306             Sarah
# 1130065    44083993  635442875  2020-07-06    149312408  Kateryna And Tim
# 1130066    44083993  635731295  2020-07-07    157258161            Martin
# 1130067    44086561  635723366  2020-07-07    346378511            Elyana
#
#                                                   comments
# 1130063  A perfect stay at Matthew’s place- the room an...
# 1130064  It was a great experience! I loved this apartm...
# 1130065  great place! Very new and stylish apartment. E...
# 1130066  Very clean apartment, new renovation and easy ...
# 1130067  The stay was great. Rory & Cory made sure our ...

# %%
revs_gz.shape
# Out:
# (1130068, 6)

# %%
revs_gz.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1130068 entries, 0 to 1130067
# Data columns (total 6 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   listing_id     1130068 non-null  int64
#  1   id             1130068 non-null  int64
#  2   date           1130068 non-null  object
#  3   reviewer_id    1130068 non-null  int64
#  4   reviewer_name  1130058 non-null  object
#  5   comments       1129351 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 51.7+ MB

# %%
revs_gz.describe()
# Out:
#          listing_id            id   reviewer_id
# count  1.130068e+06  1.130068e+06  1.130068e+06
# mean   1.463910e+07  3.169831e+08  8.927939e+07
# std    1.144450e+07  1.908521e+08  8.481721e+07
# min    2.060000e+03  1.580000e+02  1.000000e+00
# 25%    4.168812e+06  1.497051e+08  1.977672e+07
# 50%    1.353337e+07  3.166354e+08  5.948396e+07
# 75%    2.238930e+07  4.925855e+08  1.413922e+08
# max    4.408656e+07  6.359389e+08  3.536323e+08

# %%
len(revs_gz)
# Out:
# 1130068

# %%
cal_gz.head()
# Out:
#    listing_id        date available    price adjusted_price  minimum_nights  \
# 0        2060  2020-07-08         t  $100.00        $100.00             1.0
# 1       53469  2020-07-08         t   $98.00         $98.00             7.0
# 2       53469  2020-07-09         t   $98.00         $98.00             7.0
# 3       53469  2020-07-10         t  $106.00        $106.00             7.0
# 4       53469  2020-07-11         t  $106.00        $106.00             7.0
#
#    maximum_nights
# 0           730.0
# 1           365.0
# 2           365.0
# 3           365.0
# 4           365.0

# %%
cal_gz.shape
# Out:
# (17734136, 7)

# %%
cal_gz.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17734136 entries, 0 to 17734135
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   date            object
#  2   available       object
#  3   price           object
#  4   adjusted_price  object
#  5   minimum_nights  float64
#  6   maximum_nights  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 947.1+ MB

# %%
cal_gz.describe()
# Out:
#          listing_id  minimum_nights  maximum_nights
# count  1.773414e+07    1.773413e+07    1.773413e+07
# mean   2.306584e+07    1.231354e+01    9.289989e+05
# std    1.362922e+07    5.735378e+01    4.461887e+07
# min    2.060000e+03    1.000000e+00    1.000000e+00
# 25%    1.085970e+07    2.000000e+00    3.100000e+01
# 50%    2.236110e+07    3.000000e+00    1.125000e+03
# 75%    3.577160e+07    6.000000e+00    1.125000e+03
# max    4.410453e+07    1.400000e+03    2.147484e+09

# %%
len(cal_gz)
# Out:
# 17734136

# %%
pd.set_option('max_columns', None)
lsts_gz.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  2060  https://www.airbnb.com/rooms/2060  20200707031313   2020-07-08
# 1  2595  https://www.airbnb.com/rooms/2595  20200707031313   2020-07-08
# 2  3831  https://www.airbnb.com/rooms/3831  20200707031313   2020-07-08
# 3  5054  https://www.airbnb.com/rooms/5054  20200707031313   2020-07-08
# 4  5099  https://www.airbnb.com/rooms/5099  20200707031313   2020-07-07
#
#                                                 name  \
# 0                                         Modern NYC
# 1                              Skylit Midtown Castle
# 2  Whole flr w/private bdrm, bath & kitchen(pls r...
# 3                                       Midtown West
# 4          Large Cozy 1 BR Apartment In Midtown East
#
#                                              summary  \
# 0                                                NaN
# 1  Beautiful, spacious skylit studio in the heart...
# ...

# %%
lsts_gz.tail()
# Out:
#              id                            listing_url       scrape_id  \
# 48583  44103357  https://www.airbnb.com/rooms/44103357  20200707031313
# 48584  44103415  https://www.airbnb.com/rooms/44103415  20200707031313
# 48585  44103612  https://www.airbnb.com/rooms/44103612  20200707031313
# 48586  44103854  https://www.airbnb.com/rooms/44103854  20200707031313
# 48587  44104534  https://www.airbnb.com/rooms/44104534  20200707031313
#
#       last_scraped                                           name  \
# 48583   2020-07-08      Huge private room in Upper East Manhattan
# 48584   2020-07-08          Dumbo | Spacious Private Room in LOFT
# 48585   2020-07-08              Huge private room in Williamsburg
# 48586   2020-07-08                         Cozy house in Brooklyn
# 48587   2020-07-08  Stunning, spacious Upper West Side apartment!
#
#                                                  summary  \
# 48583  This apartment is located on 110th St and the ...
# ...

# %%
lsts_gz.shape
# Out:
# (48588, 106)

# %%
lsts_gz.info(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48588 entries, 0 to 48587
# Data columns (total 106 columns):
#  #   Column                                        Dtype
# ---  ------                                        -----
#  0   id                                            int64
#  1   listing_url                                   object
#  2   scrape_id                                     int64
#  3   last_scraped                                  object
#  4   name                                          object
#  5   summary                                       object
#  6   space                                         object
#  7   description                                   object
#  8   experiences_offered                           object
#  9   neighborhood_overview                         object
#  10  notes                                         object
#  11  transit                                       object
# ...

# %%
lsts_gz.describe()
# Out:
#                  id     scrape_id  thumbnail_url  medium_url  xl_picture_url  \
# count  4.858800e+04  4.858800e+04            0.0         0.0             0.0
# mean   2.306509e+07  2.020071e+13            NaN         NaN             NaN
# std    1.362972e+07  0.000000e+00            NaN         NaN             NaN
# min    2.060000e+03  2.020071e+13            NaN         NaN             NaN
# 25%    1.085637e+07  2.020071e+13            NaN         NaN             NaN
# 50%    2.236088e+07  2.020071e+13            NaN         NaN             NaN
# 75%    3.577099e+07  2.020071e+13            NaN         NaN             NaN
# max    4.410453e+07  2.020071e+13            NaN         NaN             NaN
#
#             host_id  host_listings_count  host_total_listings_count  \
# count  4.858800e+04         48576.000000               48576.000000
# mean   8.548647e+07            16.138710                  16.138710
# std    9.959082e+07           122.046309                 122.046309
# ...

# %%
len(lsts_gz)
# Out:
# 48588

# %%
# Let's start visualizing!

borough_rooms = lsts.groupby(['neighbourhood_group', 'room_type'])['id'].count().reset_index()
borough_rooms
# Out:
#    neighbourhood_group        room_type     id
# 0                Bronx  Entire home/apt    422
# 1                Bronx     Private room    724
# 2                Bronx      Shared room     46
# 3             Brooklyn  Entire home/apt   9501
# 4             Brooklyn       Hotel room     31
# 5             Brooklyn     Private room   9591
# 6             Brooklyn      Shared room    351
# 7            Manhattan  Entire home/apt  12905
# 8            Manhattan       Hotel room    351
# 9            Manhattan     Private room   7859
# 10           Manhattan      Shared room    480
# 11              Queens  Entire home/apt   2179
# 12              Queens       Hotel room     17
# 13              Queens     Private room   3574
# 14              Queens      Shared room    192
# 15       Staten Island  Entire home/apt    184
# 16       Staten Island     Private room    174
# 17       Staten Island      Shared room      7

# %%
sns.set(rc={'figure.figsize': (16, 5)})
ax = sns.barplot(x = 'neighbourhood_group', y = 'id', hue = 'room_type', data = borough_rooms, 
                 palette ='mako', ci = False)

# %%
listings_borough = lsts.groupby(['neighbourhood_group'])['id'].count().reset_index()
listings_borough
# Out:
#   neighbourhood_group     id
# 0               Bronx   1192
# 1            Brooklyn  19474
# 2           Manhattan  21595
# 3              Queens   5962
# 4       Staten Island    365

# %%
plot = listings_borough.plot.pie(y='id', figsize=(6, 6), 
                                 labels=['Bronx', 'Brooklyn', 'Manhattan', 'Queens', 'Staten Island'])
plt.legend(loc='upper left')
plt.title('Listings by Borough')
plt.show()

# %%
# Donut chart
names=[r'Bronx (2 %)', r'Brooklyn (40 %)', 
r'Manhattan (44 %)', r'Queens (12 %)', r'Staten Island (0.75 %)']
size=[1192,19474,21595,5962,365]
 
# Create a circle for the center of the plot
my_circle=plt.Circle( (0,0), 0.7, color='white')


plt.rcParams['text.color'] = 'black'
fig = plt.figure()
fig.patch.set_facecolor('white')

plt.pie(size, labels=names, colors=['blue','orange','green', 'red', 'purple'], labeldistance=1.15, 
        wedgeprops = { 'linewidth' : 7, 'edgecolor' : 'white' })
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.title('Listings by Borough')

# plt.savefig('donut.png', dpi=100)

plt.show()

# %%
lsts_gz['price']
# Out:
# 0        $100.00
# 1        $225.00
# 2         $89.00
# 3        $150.00
# 4        $200.00
#           ...
# 48583     $40.00
# 48584     $75.00
# 48585     $45.00
# 48586    $125.00
# 48587     $78.00
# Name: price, Length: 48588, dtype: object

# %%
lsts_gz['price'] = lsts_gz['price'].str.replace(',', '')
lsts_gz['price'] = lsts_gz['price'].str.replace('$','').astype(str).astype(float)

# %%
avg_prices = lsts_gz.groupby(['neighbourhood_group_cleansed', 'room_type'])['price'].mean().reset_index()
avg_prices
# Out:
#    neighbourhood_group_cleansed        room_type       price
# 0                         Bronx  Entire home/apt  136.042654
# 1                         Bronx     Private room   66.421271
# 2                         Bronx      Shared room   71.478261
# 3                      Brooklyn  Entire home/apt  175.641301
# 4                      Brooklyn       Hotel room  180.451613
# 5                      Brooklyn     Private room   75.827234
# 6                      Brooklyn      Shared room   86.421652
# 7                     Manhattan  Entire home/apt  245.620070
# 8                     Manhattan       Hotel room  291.202279
# 9                     Manhattan     Private room  195.944904
# 10                    Manhattan      Shared room  105.272917
# 11                       Queens  Entire home/apt  153.516751
# 12                       Queens       Hotel room  153.294118
# 13                       Queens     Private room   68.579743
# ...

# %%
sns.set(rc={'figure.figsize': (16, 5)})
ax = sns.barplot(x = 'neighbourhood_group_cleansed', y = 'price', hue = 'room_type', data = avg_prices, 
                 palette ='plasma_r', ci = False)

# %%
# I want to narrow the scope of this project. Let's filter the data exclusively for the year 2019.
# I'll have to split the last_review column in lsts_gz to extract the year before filtering.

# Cast last_review column as a str

lsts_gz['last_review'] = lsts_gz['last_review'].astype(str)

# %%
# Split last_review

lsts_gz[['L_Year','L_Month','L_Date']] = lsts_gz['last_review'].apply( 
   lambda x: pd.Series(str(x).split("-"))) 
lsts_gz
# Out:
#              id                            listing_url       scrape_id  \
# 0          2060      https://www.airbnb.com/rooms/2060  20200707031313
# 1          2595      https://www.airbnb.com/rooms/2595  20200707031313
# 2          3831      https://www.airbnb.com/rooms/3831  20200707031313
# 3          5054      https://www.airbnb.com/rooms/5054  20200707031313
# 4          5099      https://www.airbnb.com/rooms/5099  20200707031313
# ...         ...                                    ...             ...
# 48583  44103357  https://www.airbnb.com/rooms/44103357  20200707031313
# 48584  44103415  https://www.airbnb.com/rooms/44103415  20200707031313
# 48585  44103612  https://www.airbnb.com/rooms/44103612  20200707031313
# 48586  44103854  https://www.airbnb.com/rooms/44103854  20200707031313
# 48587  44104534  https://www.airbnb.com/rooms/44104534  20200707031313
#
#       last_scraped                                               name  \
# ...

# %%
# Filtering for 2019 only

lstgz_19= lsts_gz.loc[lsts_gz['L_Year'] == '2019']
lstgz_19
# Out:
#              id                            listing_url       scrape_id  \
# 1          2595      https://www.airbnb.com/rooms/2595  20200707031313
# 4          5099      https://www.airbnb.com/rooms/5099  20200707031313
# 5          5121      https://www.airbnb.com/rooms/5121  20200707031313
# 9          5238      https://www.airbnb.com/rooms/5238  20200707031313
# 10         5552      https://www.airbnb.com/rooms/5552  20200707031313
# ...         ...                                    ...             ...
# 43061  41023033  https://www.airbnb.com/rooms/41023033  20200707031313
# 43100  41043703  https://www.airbnb.com/rooms/41043703  20200707031313
# 43105  41047435  https://www.airbnb.com/rooms/41047435  20200707031313
# 43197  41108540  https://www.airbnb.com/rooms/41108540  20200707031313
# 43226  41133437  https://www.airbnb.com/rooms/41133437  20200707031313
#
#       last_scraped                                               name  \
# ...

# %%
# Let's revisit some older visualizations using this new subset of data

borooms_19 = lstgz_19.groupby(['neighbourhood_group_cleansed', 'room_type'])['id'].count().reset_index()
borooms_19
# Out:
#    neighbourhood_group_cleansed        room_type    id
# 0                         Bronx  Entire home/apt    66
# 1                         Bronx     Private room   150
# 2                         Bronx      Shared room    16
# 3                      Brooklyn  Entire home/apt  2012
# 4                      Brooklyn       Hotel room     6
# 5                      Brooklyn     Private room  2007
# 6                      Brooklyn      Shared room    64
# 7                     Manhattan  Entire home/apt  2310
# 8                     Manhattan       Hotel room    60
# 9                     Manhattan     Private room  1489
# 10                    Manhattan      Shared room    87
# 11                       Queens  Entire home/apt   373
# 12                       Queens     Private room   813
# 13                       Queens      Shared room    44
# 14                Staten Island  Entire home/apt    20
# 15                Staten Island     Private room    37
# ...

# %%
sns.set(rc={'figure.figsize': (16, 5)})
ax = sns.barplot(x = 'neighbourhood_group_cleansed', y = 'id', hue = 'room_type', data = borooms_19, 
                 palette ='mako', ci = False)

# %%
avprices_19 = lstgz_19.groupby(['neighbourhood_group_cleansed', 'room_type'])['price'].mean().reset_index()
avprices_19
# Out:
#    neighbourhood_group_cleansed        room_type       price
# 0                         Bronx  Entire home/apt  172.621212
# 1                         Bronx     Private room   66.066667
# 2                         Bronx      Shared room   43.250000
# 3                      Brooklyn  Entire home/apt  176.088469
# 4                      Brooklyn       Hotel room  144.166667
# 5                      Brooklyn     Private room   73.327354
# 6                      Brooklyn      Shared room   46.093750
# 7                     Manhattan  Entire home/apt  219.050216
# 8                     Manhattan       Hotel room  253.050000
# 9                     Manhattan     Private room  122.793821
# 10                    Manhattan      Shared room  191.850575
# 11                       Queens  Entire home/apt  149.179625
# 12                       Queens     Private room   66.931119
# 13                       Queens      Shared room  123.931818
# ...

# %%
sns.set(rc={'figure.figsize': (16, 5)})
ax = sns.barplot(x = 'neighbourhood_group_cleansed', y = 'price', hue = 'room_type', data = avprices_19, 
                 palette ='plasma_r', ci = False)

# %%
# A quick look at 2018 listings to compare Airbnb's growth

lstgz_18= lsts_gz.loc[lsts_gz['L_Year'] == '2018']
lstgz_18
# Out:
#              id                            listing_url       scrape_id  \
# 13         6090      https://www.airbnb.com/rooms/6090  20200707031313
# 46        15396     https://www.airbnb.com/rooms/15396  20200707031313
# 76        20913     https://www.airbnb.com/rooms/20913  20200707031313
# 80        22911     https://www.airbnb.com/rooms/22911  20200707031313
# 85        24285     https://www.airbnb.com/rooms/24285  20200707031313
# ...         ...                                    ...             ...
# 31997  31038390  https://www.airbnb.com/rooms/31038390  20200707031313
# 32008  31042971  https://www.airbnb.com/rooms/31042971  20200707031313
# 32030  31057368  https://www.airbnb.com/rooms/31057368  20200707031313
# 32031  31057394  https://www.airbnb.com/rooms/31057394  20200707031313
# 32166  31149465  https://www.airbnb.com/rooms/31149465  20200707031313
#
#       last_scraped                                               name  \
# ...

# %%
borooms_18 = lstgz_18.groupby(['neighbourhood_group_cleansed', 'room_type'])['id'].count().reset_index()
borooms_18
# Out:
#    neighbourhood_group_cleansed        room_type   id
# 0                         Bronx  Entire home/apt   21
# 1                         Bronx     Private room   52
# 2                         Bronx      Shared room    2
# 3                      Brooklyn  Entire home/apt  730
# 4                      Brooklyn     Private room  858
# 5                      Brooklyn      Shared room   27
# 6                     Manhattan  Entire home/apt  939
# 7                     Manhattan       Hotel room    5
# 8                     Manhattan     Private room  627
# 9                     Manhattan      Shared room   23
# 10                       Queens  Entire home/apt  110
# 11                       Queens       Hotel room    1
# 12                       Queens     Private room  226
# 13                       Queens      Shared room   11
# 14                Staten Island  Entire home/apt    8
# 15                Staten Island     Private room   10
# ...

# %%
# Checking 2020 data out of curiosity!

lstgz_20= lsts_gz.loc[lsts_gz['L_Year'] == '2020']
lstgz_20
# Out:
#              id                            listing_url       scrape_id  \
# 2          3831      https://www.airbnb.com/rooms/3831  20200707031313
# 7          5178      https://www.airbnb.com/rooms/5178  20200707031313
# 11         5803      https://www.airbnb.com/rooms/5803  20200707031313
# 14         6848      https://www.airbnb.com/rooms/6848  20200707031313
# 16         7097      https://www.airbnb.com/rooms/7097  20200707031313
# ...         ...                                    ...             ...
# 48383  44004796  https://www.airbnb.com/rooms/44004796  20200707031313
# 48422  44020492  https://www.airbnb.com/rooms/44020492  20200707031313
# 48495  44054321  https://www.airbnb.com/rooms/44054321  20200707031313
# 48553  44083993  https://www.airbnb.com/rooms/44083993  20200707031313
# 48557  44086561  https://www.airbnb.com/rooms/44086561  20200707031313
#
#       last_scraped                                               name  \
# ...

# %%
borooms_20 = lstgz_20.groupby(['neighbourhood_group_cleansed', 'room_type'])['id'].count().reset_index()
borooms_20
# Out:
#    neighbourhood_group_cleansed        room_type    id
# 0                         Bronx  Entire home/apt   249
# 1                         Bronx     Private room   350
# 2                         Bronx      Shared room     9
# 3                      Brooklyn  Entire home/apt  3918
# 4                      Brooklyn       Hotel room    21
# 5                      Brooklyn     Private room  2964
# 6                      Brooklyn      Shared room    93
# 7                     Manhattan  Entire home/apt  4141
# 8                     Manhattan       Hotel room   167
# 9                     Manhattan     Private room  2509
# 10                    Manhattan      Shared room   197
# 11                       Queens  Entire home/apt  1140
# 12                       Queens       Hotel room    13
# 13                       Queens     Private room  1438
# 14                       Queens      Shared room    76
# 15                Staten Island  Entire home/apt   122
# ...

# %%
# Had to refocus POV to only reflect insights from these sets of data (no outside data permitted).
# Now an analyst at an online travel agency startup
# Why use Airbnb and their data? Let's examine Airbnb growth in NYC from 2018 to 2020.
# (Use previously made variables. Make maps showing average listings by area!)
# Take the lstgz_18, lstgz_19, and lstgz_20 and save them to csvs. Use these csvs in Tableau to create maps!

# %%
# (Active) listings for given years based on being reviewed during those years.
lstgz_18.to_csv('lstsgz_18.csv', sep=',')
lstgz_19.to_csv('lstsgz_19.csv', sep=',')
lstgz_20.to_csv('lstsgz_20.csv', sep=',')

# %%
# Since the most important data we could use for this analysis is the most current: let's keep things at 2020.
# Review listings and average prices (across boroughs) for 2020.

# %%
avprices_20 = lstgz_20.groupby(['neighbourhood_group_cleansed', 'room_type'])['price'].mean().reset_index()
avprices_20
# Out:
#    neighbourhood_group_cleansed        room_type       price
# 0                         Bronx  Entire home/apt  117.610442
# 1                         Bronx     Private room   58.777143
# 2                         Bronx      Shared room   43.333333
# 3                      Brooklyn  Entire home/apt  164.643951
# 4                      Brooklyn       Hotel room  160.952381
# 5                      Brooklyn     Private room   72.314103
# 6                      Brooklyn      Shared room   41.989247
# 7                     Manhattan  Entire home/apt  236.388553
# 8                     Manhattan       Hotel room  328.167665
# 9                     Manhattan     Private room  212.577919
# 10                    Manhattan      Shared room   66.578680
# 11                       Queens  Entire home/apt  139.832456
# 12                       Queens       Hotel room  173.153846
# 13                       Queens     Private room   63.557719
# ...

# %%
sns.set(rc={'figure.figsize': (16, 5)})
ax = sns.barplot(x = 'neighbourhood_group_cleansed', y = 'id', hue = 'room_type', data = borooms_20, 
                 palette ='mako', ci = False)
plt.xlabel('Borough', fontweight='bold')
plt.ylabel('Total Listings', fontweight='bold')
plt.title('2020 Total Listings by Borough and Room Type', fontweight='bold')
# Out:
# Text(0.5, 1.0, '2020 Total Listings by Borough and Room Type')

# %%
sns.set(rc={'figure.figsize': (16, 5)})
ax = sns.barplot(x = 'neighbourhood_group_cleansed', y = 'price', hue = 'room_type', data = avprices_19, 
                 palette ='plasma_r', ci = False)
plt.xlabel('Borough', fontweight='bold')
plt.ylabel('Average Price', fontweight='bold')
plt.title('2020 Average Prices by Borough and Room Type', fontweight='bold')
# Out:
# Text(0.5, 1.0, '2020 Average Prices by Borough and Room Type')

# %%
# So the highest concentrations of listings are in Manhattan and Brooklyn. But those numbers aren't everything!
# We need to find the best listings of the year, taking into account price, amenities, entertainment, host reviews, 
# and cleanliness! We care about the *experience* of the package we offer, not just the price!

# %%
# Donut chart
names=[r'Bronx (3 %)', r'Brooklyn (40 %)', 
r'Manhattan (41 %)', r'Queens (15 %)', r'Staten Island (1 %)']
size=[608,6996,7014,2667,219]
 
# Create a circle for the center of the plot
my_circle=plt.Circle( (0,0), 0.7, color='white')


plt.rcParams['text.color'] = 'black'
fig = plt.figure()
fig.patch.set_facecolor('white')

plt.pie(size, labels=names, colors=['blue','orange','green', 'red', 'purple'], labeldistance=1.15, 
        wedgeprops = { 'linewidth' : 7, 'edgecolor' : 'white' })
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.title('2020 Active Listings by Borough', fontweight='bold')

# plt.savefig('donut.png', dpi=100)

plt.show()

# %%
# Create a new DataFrame with most relvant info
manhattan = lstgz_20.loc[lstgz_20['neighbourhood_group_cleansed'] == 'Manhattan']
manhattan
# Out:
#              id                            listing_url       scrape_id  \
# 7          5178      https://www.airbnb.com/rooms/5178  20200707031313
# 22         9668      https://www.airbnb.com/rooms/9668  20200707031313
# 23         9704      https://www.airbnb.com/rooms/9704  20200707031313
# 24         9783      https://www.airbnb.com/rooms/9783  20200707031313
# 29        12192     https://www.airbnb.com/rooms/12192  20200707031313
# ...         ...                                    ...             ...
# 48179  43894383  https://www.airbnb.com/rooms/43894383  20200707031313
# 48192  43899120  https://www.airbnb.com/rooms/43899120  20200707031313
# 48311  43965128  https://www.airbnb.com/rooms/43965128  20200707031313
# 48325  43968934  https://www.airbnb.com/rooms/43968934  20200707031313
# 48371  44000456  https://www.airbnb.com/rooms/44000456  20200707031313
#
#       last_scraped                                               name  \
# ...

# %%
manhattan2 = manhattan[['id', 'listing_url', 'experiences_offered', 'neighborhood_overview', 'notes', 'transit', 'interaction', 
                      'house_rules', 'host_id', 'host_response_time', 'host_response_rate', 'host_acceptance_rate',
                     'host_is_superhost', 'host_listings_count', 'host_total_listings_count', 
                      'neighbourhood_group_cleansed', 'zipcode', 'latitude', 'longitude', 'property_type', 
                      'room_type','amenities', 'price', 'number_of_reviews', 'number_of_reviews_ltm', 'first_review',
                     'last_review', 'review_scores_rating', 'review_scores_cleanliness', 
                      'review_scores_communication', 'review_scores_location', 'review_scores_value', 
                      'reviews_per_month', 'L_Year', 'L_Month', 'L_Date']]
manhattan2
# Out:
#              id                            listing_url experiences_offered  \
# 7          5178      https://www.airbnb.com/rooms/5178                none
# 22         9668      https://www.airbnb.com/rooms/9668                none
# 23         9704      https://www.airbnb.com/rooms/9704                none
# 24         9783      https://www.airbnb.com/rooms/9783                none
# 29        12192     https://www.airbnb.com/rooms/12192                none
# ...         ...                                    ...                 ...
# 48179  43894383  https://www.airbnb.com/rooms/43894383                none
# 48192  43899120  https://www.airbnb.com/rooms/43899120                none
# 48311  43965128  https://www.airbnb.com/rooms/43965128                none
# 48325  43968934  https://www.airbnb.com/rooms/43968934                none
# 48371  44000456  https://www.airbnb.com/rooms/44000456                none
#
#                                    neighborhood_overview  \
# ...

# %%
man_rates = manhattan2['review_scores_rating'].mean()

# %%
man_clean = manhattan2['review_scores_cleanliness'].mean()

# %%
manhattan2['review_scores_cleanliness'].min()
# Out:
# 2.0

# %%
manhattan2['review_scores_cleanliness'].max()
# Out:
# 10.0

# %%
man_revs = manhattan2['number_of_reviews'].mean()

# %%
man_price = manhattan2['price'].mean()

# %%
manhattan2['price'].max()
# Out:
# 10000.0

# %%
manhattan2['price'].min()
# Out:
# 0.0

# %%
# How is there a nightly price of $0.00?????!
zeros = manhattan2.loc[manhattan2['price'] == 0.0]
zeros
# These two listings must have been updated since the data was scraped. Will drop as they skew the pricing.
# Out:
#              id                            listing_url experiences_offered  \
# 40869  39722994  https://www.airbnb.com/rooms/39722994                none
# 44317  41940603  https://www.airbnb.com/rooms/41940603                none
#
#       neighborhood_overview  \
# 40869                   NaN
# 44317                   NaN
#
#                                                    notes transit interaction  \
# 40869  The listing address is approximate one , once ...     NaN         NaN
# 44317                                                NaN     NaN         NaN
#
#                                              house_rules    host_id  \
# 40869  Long term reservations , 28 days or more , MUS...   17655093
# 44317                                                NaN  318692171
#
#       host_response_time host_response_rate host_acceptance_rate  \
# 40869       within a day                60%                  75%
# 44317       within a day                56%                  93%
#
# ...

# %%
# Resetting index before dropping
manhattan2 = manhattan2.reset_index()

# %%
# Dropping them
manhattan2.drop(manhattan2.index[[5591,6484]], axis=0, inplace=True)
manhattan2
# Out:
#       index        id                            listing_url  \
# 0         7      5178      https://www.airbnb.com/rooms/5178
# 1        22      9668      https://www.airbnb.com/rooms/9668
# 2        23      9704      https://www.airbnb.com/rooms/9704
# 3        24      9783      https://www.airbnb.com/rooms/9783
# 4        29     12192     https://www.airbnb.com/rooms/12192
# ...     ...       ...                                    ...
# 7009  48179  43894383  https://www.airbnb.com/rooms/43894383
# 7010  48192  43899120  https://www.airbnb.com/rooms/43899120
# 7011  48311  43965128  https://www.airbnb.com/rooms/43965128
# 7012  48325  43968934  https://www.airbnb.com/rooms/43968934
# 7013  48371  44000456  https://www.airbnb.com/rooms/44000456
#
#      experiences_offered                              neighborhood_overview  \
# 0                   none    Theater district, many restaurants around here.
# 1                   none  Just about everything you will ever need is wi...
# ...

# %%
# Further filtering the dataset to find the best listings!
manhattan3 = manhattan2.loc[(manhattan2['review_scores_rating'] >= man_rates) & 
               (manhattan2['review_scores_cleanliness'] >= man_clean)]
manhattan3.head(3)
# Out:
#     index     id                         listing_url experiences_offered  \
# 8      54  16580  https://www.airbnb.com/rooms/16580                none
# 10     57  16974  https://www.airbnb.com/rooms/16974                none
# 11     58  17037  https://www.airbnb.com/rooms/17037                none
#
#                                 neighborhood_overview  \
# 8   East Village/ Alphabet City has tons of cafes ...
# 10                                                NaN
# 11  The neighborhood is friendly, active, and the ...
#
#                                                 notes  \
# 8   Please note this room shares a bathroom with t...
# 10  I will be happy to arrange transportation to a...
# 11  Don't be surprised that a tenement apt only ha...
#
#                                               transit  \
# 8   The L train is about a 10+ min walk, but pleas...
# 10  The subway is five minutes away - buses even c...
# 11  You've got the F train, the L train, and buses...
#
# ...

# %%
manhattan4 = manhattan3.loc[manhattan3['number_of_reviews'] >= man_revs]
manhattan4
# Out:
#       index        id                            listing_url  \
# 8        54     16580     https://www.airbnb.com/rooms/16580
# 10       57     16974     https://www.airbnb.com/rooms/16974
# 11       58     17037     https://www.airbnb.com/rooms/17037
# 13       65     18728     https://www.airbnb.com/rooms/18728
# 14       67     19159     https://www.airbnb.com/rooms/19159
# ...     ...       ...                                    ...
# 4897  37423  36793927  https://www.airbnb.com/rooms/36793927
# 5009  38082  37493902  https://www.airbnb.com/rooms/37493902
# 5153  38715  38115292  https://www.airbnb.com/rooms/38115292
# 5192  38907  38261803  https://www.airbnb.com/rooms/38261803
# 5436  40062  39190658  https://www.airbnb.com/rooms/39190658
#
#      experiences_offered                              neighborhood_overview  \
# 8                   none  East Village/ Alphabet City has tons of cafes ...
# 10                  none                                                NaN
# ...

# %%
# Listings where response time and rate have no input? That's a no-no. They'll be dropped. Reset the index!
manhattan4.reset_index()
# Out:
#      level_0  index        id                            listing_url  \
# 0          8     54     16580     https://www.airbnb.com/rooms/16580
# 1         10     57     16974     https://www.airbnb.com/rooms/16974
# 2         11     58     17037     https://www.airbnb.com/rooms/17037
# 3         13     65     18728     https://www.airbnb.com/rooms/18728
# 4         14     67     19159     https://www.airbnb.com/rooms/19159
# ..       ...    ...       ...                                    ...
# 963     4897  37423  36793927  https://www.airbnb.com/rooms/36793927
# 964     5009  38082  37493902  https://www.airbnb.com/rooms/37493902
# 965     5153  38715  38115292  https://www.airbnb.com/rooms/38115292
# 966     5192  38907  38261803  https://www.airbnb.com/rooms/38261803
# 967     5436  40062  39190658  https://www.airbnb.com/rooms/39190658
#
#     experiences_offered                              neighborhood_overview  \
# ...

# %%
manhattan4[manhattan4['host_response_time'].isnull()]
# Out:
#       index        id                            listing_url  \
# 11       58     17037     https://www.airbnb.com/rooms/17037
# 13       65     18728     https://www.airbnb.com/rooms/18728
# 25      128     36703     https://www.airbnb.com/rooms/36703
# 34      189     57618     https://www.airbnb.com/rooms/57618
# 45      221     63003     https://www.airbnb.com/rooms/63003
# ...     ...       ...                                    ...
# 3992  33043  32291916  https://www.airbnb.com/rooms/32291916
# 4158  33945  33416167  https://www.airbnb.com/rooms/33416167
# 4180  34061  33534624  https://www.airbnb.com/rooms/33534624
# 4264  34462  33987887  https://www.airbnb.com/rooms/33987887
# 4733  36424  35766124  https://www.airbnb.com/rooms/35766124
#
#      experiences_offered                              neighborhood_overview  \
# 11                  none  The neighborhood is friendly, active, and the ...
# 13                  none  The High Line starts just a few minutes away f...
# ...

# %%
manhattan4[manhattan4['host_response_rate'].isnull()]
# Out:
#       index        id                            listing_url  \
# 11       58     17037     https://www.airbnb.com/rooms/17037
# 13       65     18728     https://www.airbnb.com/rooms/18728
# 25      128     36703     https://www.airbnb.com/rooms/36703
# 34      189     57618     https://www.airbnb.com/rooms/57618
# 45      221     63003     https://www.airbnb.com/rooms/63003
# ...     ...       ...                                    ...
# 3992  33043  32291916  https://www.airbnb.com/rooms/32291916
# 4158  33945  33416167  https://www.airbnb.com/rooms/33416167
# 4180  34061  33534624  https://www.airbnb.com/rooms/33534624
# 4264  34462  33987887  https://www.airbnb.com/rooms/33987887
# 4733  36424  35766124  https://www.airbnb.com/rooms/35766124
#
#      experiences_offered                              neighborhood_overview  \
# 11                  none  The neighborhood is friendly, active, and the ...
# 13                  none  The High Line starts just a few minutes away f...
# ...

# %%
manhattan4[manhattan4['interaction'].isnull()]
# Out:
#       index        id                            listing_url  \
# 10       57     16974     https://www.airbnb.com/rooms/16974
# 13       65     18728     https://www.airbnb.com/rooms/18728
# 42      204     60666     https://www.airbnb.com/rooms/60666
# 60      284     75635     https://www.airbnb.com/rooms/75635
# 71      343    114229    https://www.airbnb.com/rooms/114229
# ...     ...       ...                                    ...
# 4161  33960  33430847  https://www.airbnb.com/rooms/33430847
# 4168  33999  33473125  https://www.airbnb.com/rooms/33473125
# 4181  34063  33546025  https://www.airbnb.com/rooms/33546025
# 4234  34292  33781532  https://www.airbnb.com/rooms/33781532
# 4504  35467  34908245  https://www.airbnb.com/rooms/34908245
#
#      experiences_offered                              neighborhood_overview  \
# 10                  none                                                NaN
# 13                  none  The High Line starts just a few minutes away f...
# ...

# %%
manhattan4.loc[manhattan4['experiences_offered'] != 'none']
# Out:
# Empty DataFrame
# Columns: [index, id, listing_url, experiences_offered, neighborhood_overview, notes, transit, interaction, house_rules, host_id, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, neighbourhood_group_cleansed, zipcode, latitude, longitude, property_type, room_type, amenities, price, number_of_reviews, number_of_reviews_ltm, first_review, last_review, review_scores_rating, review_scores_cleanliness, review_scores_communication, review_scores_location, review_scores_value, reviews_per_month, L_Year, L_Month, L_Date]
# Index: []

# %%
manhattan4 = manhattan4[manhattan4['host_response_time'].notnull()]
manhattan4
# Out:
#       index        id                            listing_url  \
# 8        54     16580     https://www.airbnb.com/rooms/16580
# 10       57     16974     https://www.airbnb.com/rooms/16974
# 14       67     19159     https://www.airbnb.com/rooms/19159
# 17       88     25696     https://www.airbnb.com/rooms/25696
# 23      108     29683     https://www.airbnb.com/rooms/29683
# ...     ...       ...                                    ...
# 4897  37423  36793927  https://www.airbnb.com/rooms/36793927
# 5009  38082  37493902  https://www.airbnb.com/rooms/37493902
# 5153  38715  38115292  https://www.airbnb.com/rooms/38115292
# 5192  38907  38261803  https://www.airbnb.com/rooms/38261803
# 5436  40062  39190658  https://www.airbnb.com/rooms/39190658
#
#      experiences_offered                              neighborhood_overview  \
# 8                   none  East Village/ Alphabet City has tons of cafes ...
# 10                  none                                                NaN
# ...

# %%
manhattan4 = manhattan4[manhattan4['host_response_rate'].notnull()]
manhattan4
# Out:
#       index        id                            listing_url  \
# 8        54     16580     https://www.airbnb.com/rooms/16580
# 10       57     16974     https://www.airbnb.com/rooms/16974
# 14       67     19159     https://www.airbnb.com/rooms/19159
# 17       88     25696     https://www.airbnb.com/rooms/25696
# 23      108     29683     https://www.airbnb.com/rooms/29683
# ...     ...       ...                                    ...
# 4897  37423  36793927  https://www.airbnb.com/rooms/36793927
# 5009  38082  37493902  https://www.airbnb.com/rooms/37493902
# 5153  38715  38115292  https://www.airbnb.com/rooms/38115292
# 5192  38907  38261803  https://www.airbnb.com/rooms/38261803
# 5436  40062  39190658  https://www.airbnb.com/rooms/39190658
#
#      experiences_offered                              neighborhood_overview  \
# 8                   none  East Village/ Alphabet City has tons of cafes ...
# 10                  none                                                NaN
# ...

# %%
manhattan4.reset_index()
# Out:
#      level_0  index        id                            listing_url  \
# 0          8     54     16580     https://www.airbnb.com/rooms/16580
# 1         10     57     16974     https://www.airbnb.com/rooms/16974
# 2         14     67     19159     https://www.airbnb.com/rooms/19159
# 3         17     88     25696     https://www.airbnb.com/rooms/25696
# 4         23    108     29683     https://www.airbnb.com/rooms/29683
# ..       ...    ...       ...                                    ...
# 629     4897  37423  36793927  https://www.airbnb.com/rooms/36793927
# 630     5009  38082  37493902  https://www.airbnb.com/rooms/37493902
# 631     5153  38715  38115292  https://www.airbnb.com/rooms/38115292
# 632     5192  38907  38261803  https://www.airbnb.com/rooms/38261803
# 633     5436  40062  39190658  https://www.airbnb.com/rooms/39190658
#
#     experiences_offered                              neighborhood_overview  \
# ...

# %%
# Dropping extra index columns
manhattan4.drop(manhattan4.columns[0:1], axis=1, inplace=True)

# %%
manhattan4
# Out:
#             id                            listing_url experiences_offered  \
# 8        16580     https://www.airbnb.com/rooms/16580                none
# 10       16974     https://www.airbnb.com/rooms/16974                none
# 14       19159     https://www.airbnb.com/rooms/19159                none
# 17       25696     https://www.airbnb.com/rooms/25696                none
# 23       29683     https://www.airbnb.com/rooms/29683                none
# ...        ...                                    ...                 ...
# 4897  36793927  https://www.airbnb.com/rooms/36793927                none
# 5009  37493902  https://www.airbnb.com/rooms/37493902                none
# 5153  38115292  https://www.airbnb.com/rooms/38115292                none
# 5192  38261803  https://www.airbnb.com/rooms/38261803                none
# 5436  39190658  https://www.airbnb.com/rooms/39190658                none
#
#                                   neighborhood_overview  \
# ...

# %%
manhattan_prime = manhattan4[manhattan4['interaction'].notnull()]
manhattan_prime
# Out:
#             id                            listing_url experiences_offered  \
# 8        16580     https://www.airbnb.com/rooms/16580                none
# 14       19159     https://www.airbnb.com/rooms/19159                none
# 17       25696     https://www.airbnb.com/rooms/25696                none
# 23       29683     https://www.airbnb.com/rooms/29683                none
# 24       31130     https://www.airbnb.com/rooms/31130                none
# ...        ...                                    ...                 ...
# 4897  36793927  https://www.airbnb.com/rooms/36793927                none
# 5009  37493902  https://www.airbnb.com/rooms/37493902                none
# 5153  38115292  https://www.airbnb.com/rooms/38115292                none
# 5192  38261803  https://www.airbnb.com/rooms/38261803                none
# 5436  39190658  https://www.airbnb.com/rooms/39190658                none
#
#                                   neighborhood_overview  \
# ...

# %%
manhattan_prime.reset_index()
# Out:
#      index        id                            listing_url  \
# 0        8     16580     https://www.airbnb.com/rooms/16580
# 1       14     19159     https://www.airbnb.com/rooms/19159
# 2       17     25696     https://www.airbnb.com/rooms/25696
# 3       23     29683     https://www.airbnb.com/rooms/29683
# 4       24     31130     https://www.airbnb.com/rooms/31130
# ..     ...       ...                                    ...
# 501   4897  36793927  https://www.airbnb.com/rooms/36793927
# 502   5009  37493902  https://www.airbnb.com/rooms/37493902
# 503   5153  38115292  https://www.airbnb.com/rooms/38115292
# 504   5192  38261803  https://www.airbnb.com/rooms/38261803
# 505   5436  39190658  https://www.airbnb.com/rooms/39190658
#
#     experiences_offered                              neighborhood_overview  \
# 0                  none  East Village/ Alphabet City has tons of cafes ...
# 1                  none  After walking all day downtown in the crowded ...
# ...

# %%
manhattan2['review_scores_communication'].mean()
# Out:
# 9.701736759006746

# %%
manhattan2['price'].min()
# Out:
# 10.0

# %%
mean_price = manhattan2['price'].mean()

# %%
# manhattan2.loc[manhattan2['price'] <= 100.0]

# %%
manhattan2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7012 entries, 0 to 7013
# Data columns (total 37 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   index                         7012 non-null   int64
#  1   id                            7012 non-null   int64
#  2   listing_url                   7012 non-null   object
#  3   experiences_offered           7012 non-null   object
#  4   neighborhood_overview         4990 non-null   object
#  5   notes                         3391 non-null   object
#  6   transit                       4966 non-null   object
#  7   interaction                   4578 non-null   object
#  8   house_rules                   4549 non-null   object
#  9   host_id                       7012 non-null   int64
#  10  host_response_time            4803 non-null   object
#  11  host_response_rate            4803 non-null   object
# ...

# %%
# Line graph of bookings month over month in 2020 (general)
gen20_bookings = manhattan2.groupby(['L_Month'])['id'].count().reset_index()
gen20_bookings
# Out:
#   L_Month    id
# 0      01  1600
# 1      02  1072
# 2      03  2373
# 3      04   339
# 4      05   460
# 5      06   915
# 6      07   253

# %%
sns.set(rc={'figure.figsize': (16, 5)})
l = ['01', '02', '03', '04', '05', '06', '07']
x = ['January', 'February', 'March', 'April', 'May', 'June', 'July']
ax = sns.lineplot(x="L_Month", y="id", data=gen20_bookings)
ax.set_xticks(l)
ax.set_xticklabels(x)
plt.xlabel('Month', fontweight='bold')
plt.ylabel('Count of Bookings', fontweight='bold')
plt.title('2020 Bookings Over Time', fontweight='bold')
# Out:
# Text(0.5, 1.0, '2020 Bookings Over Time')

# %%
exp20_bookings = manhattan2.groupby(['room_type', 'L_Month'])['id'].count().reset_index()
exp20_bookings
# Out:
#           room_type L_Month    id
# 0   Entire home/apt      01   966
# 1   Entire home/apt      02   645
# 2   Entire home/apt      03  1220
# 3   Entire home/apt      04   213
# 4   Entire home/apt      05   320
# 5   Entire home/apt      06   612
# 6   Entire home/apt      07   163
# 7        Hotel room      01    25
# 8        Hotel room      02    33
# 9        Hotel room      03    64
# 10       Hotel room      04     2
# 11       Hotel room      05     9
# 12       Hotel room      06    31
# 13       Hotel room      07     3
# 14     Private room      01   576
# 15     Private room      02   359
# 16     Private room      03   998
# 17     Private room      04   115
# 18     Private room      05   124
# 19     Private room      06   258
# 20     Private room      07    79
# 21      Shared room      01    33
# 22      Shared room      02    35
# 23      Shared room      03    91
# 24      Shared room      04     9
# 25      Shared room      05     7
# ...

# %%
# Line graph reflecting bookings by room type
sns.set(rc={'figure.figsize': (16, 5)})
l = ['01', '02', '03', '04', '05', '06', '07']
x = ['January', 'February', 'March', 'April', 'May', 'June', 'July']
ax = sns.lineplot(x='L_Month', y='id', hue='room_type', data=exp20_bookings)
ax.set_xticks(l)
ax.set_xticklabels(x)
plt.xlabel('Month', fontweight='bold')
plt.ylabel('Count of Bookings', fontweight='bold')
plt.title('2020 Bookings by Room Type', fontweight='bold')
# Out:
# Text(0.5, 1.0, '2020 Bookings by Room Type')

# %%
# Now that we've narrowed our listings to ~500, let's get some final stats/visualizations from it.

# %%
manhattan_prime['price'].min()
# Out:
# 31.0

# %%
manhattan_prime['price'].max()
# Out:
# 2000.0

# %%
manhattan_prime['price'].mean()
# Out:
# 183.82806324110672

# %%
# Average prices of the final set by room type
avprices_p = manhattan_prime.groupby(['room_type'])['price'].mean().reset_index()
avprices_p
# Out:
#          room_type       price
# 0  Entire home/apt  239.277592
# 1       Hotel room  532.200000
# 2     Private room   93.808081
# 3      Shared room   59.500000

# %%
# Accompanying graph
sns.set(rc={'figure.figsize': (10, 5)})
ax = sns.barplot(x = 'room_type', y = 'price', hue = 'room_type', data = avprices_p, 
                 palette ='plasma_r', ci = False)
plt.xlabel('Room Type', fontweight='bold')
plt.ylabel('Average Price', fontweight='bold')
plt.title('Bookazon Selections: Average Price by Room Type', fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Bookazon Selections: Average Price by Room Type')

# %%
# Count of listings of final set by room type
borooms_p = manhattan_prime.groupby(['room_type'])['id'].count().reset_index()
borooms_p
# Out:
#          room_type   id
# 0  Entire home/apt  299
# 1       Hotel room    5
# 2     Private room  198
# 3      Shared room    4

# %%
# Accompanying graph
sns.set(rc={'figure.figsize': (10, 5)})
ax = sns.barplot(x = 'room_type', y = 'id', hue='room_type', data = borooms_p, 
                 palette ='mako', ci = False)
plt.xlabel('Room Type', fontweight='bold')
plt.ylabel('Total Listings', fontweight='bold')
plt.title('Bookazon Selects: Total Listings by Room Type', fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Bookazon Selects: Total Listings by Room Type')

# %%
# Donut chart breaking down distribution of room types in the final set
# Donut chart
names=[r'Entire home/apt (59 %)', r'Hotel room (1 %)', 
r'Private room (39 %)', r'Shared room (1 %)']
size=[299, 5, 198, 4]
 
# Create a circle for the center of the plot
my_circle=plt.Circle( (0,0), 0.7, color='white')


plt.rcParams['text.color'] = 'black'
fig = plt.figure()
fig.patch.set_facecolor('white')

plt.pie(size, labels=names, colors=['blue','orange','green', 'purple'], labeldistance=1.15, 
        wedgeprops = { 'linewidth' : 7, 'edgecolor' : 'white' })
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.title('Bookazon Selects: Distribution of Listings by Room Type', fontweight='bold')

# plt.savefig('donut.png', dpi=100)

plt.show()

# %%
# Maybe do a histogram reflecting frequency of listings at given prices? (range 30-2000)
# Create an array containing data from the DataFrame
x = manhattan_prime['price'].values

sns.distplot(x)

# %%
mn = manhattan_prime['price'].mean()
# mn

sns.distplot(x)

# plt.axvline(mean, distance from x axis, length of line, color = 'red')
# we choose 1 as length of line because it's max value of a histogram 

plt.axvline(mn,0, 1, color = 'red')
plt.title('Distribution of Prices', fontweight='bold')
plt.xlabel('Price', fontweight='bold')
plt.ylabel('Frequency', fontweight='bold')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Final visualization in Tableau (map reflecting locations of manhattan_prime listings)
manhattan_prime.to_csv('manhattan_prime.csv', sep=',')

# %%
manhattan_prime.loc[manhattan_prime['price'] <= mn]
# Out:
#             id                            listing_url experiences_offered  \
# 8        16580     https://www.airbnb.com/rooms/16580                none
# 14       19159     https://www.airbnb.com/rooms/19159                none
# 17       25696     https://www.airbnb.com/rooms/25696                none
# 24       31130     https://www.airbnb.com/rooms/31130                none
# 32       54860     https://www.airbnb.com/rooms/54860                none
# ...        ...                                    ...                 ...
# 4310  34172085  https://www.airbnb.com/rooms/34172085                none
# 4589  35257081  https://www.airbnb.com/rooms/35257081                none
# 4691  35601668  https://www.airbnb.com/rooms/35601668                none
# 4897  36793927  https://www.airbnb.com/rooms/36793927                none
# 5192  38261803  https://www.airbnb.com/rooms/38261803                none
#
#                                   neighborhood_overview  \
# ...

# %%
# 321 of 505 rows are under the average price. That's 64 percent of all listings! (this info goes well with the hist!)

# %%
# Saving visualizations to .png files for presentation imports
# plt.savefig('graph_name.png', dpi=100)

# %%
mn
# Out:
# 183.82806324110672
